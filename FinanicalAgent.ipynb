# %%
# !pip install langchain langchain-community langchain-core langchain-groq faiss-cpu sentence-transformers docling
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (0.3.27)
# Collecting langchain-community
#   Downloading langchain_community-0.3.29-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.12/dist-packages (0.3.74)
# Collecting langchain-groq
#   Downloading langchain_groq-0.3.7-py3-none-any.whl.metadata (2.6 kB)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (5.1.0)
# Collecting docling
#   Downloading docling-2.48.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.4.16)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain) (6.0.2)
# Collecting langchain-core
#   Downloading langchain_core-0.3.75-py3-none-any.whl.metadata (5.7 kB)
# Collecting requests<3,>=2 (from langchain)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.12.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (8.5.0)
# Collecting dataclasses-json<0.7,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.1)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (25.0)
# Collecting groq<1,>=0.30.0 (from langchain-groq)
#   Downloading groq-0.31.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.55.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (2.8.0+cu126)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (1.16.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (0.34.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from sentence-transformers) (11.3.0)
# Collecting docling-core<3.0.0,>=2.42.0 (from docling-core[chunking]<3.0.0,>=2.42.0->docling)
#   Downloading docling_core-2.45.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting docling-parse<5.0.0,>=4.2.2 (from docling)
#   Downloading docling_parse-4.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.5 kB)
# Collecting docling-ibm-models<4,>=3.9.0 (from docling)
#   Downloading docling_ibm_models-3.9.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from docling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting pypdfium2!=4.30.1,<5.0.0,>=4.30.0 (from docling)
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.5 MB/s eta 0:00:00
# Collecting easyocr<2.0,>=1.7 (from docling)
#   Downloading easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: certifi>=2024.7.4 in /usr/local/lib/python3.12/dist-packages (from docling) (2025.8.3)
# Collecting rtree<2.0.0,>=1.3.0 (from docling)
#   Downloading rtree-1.4.1-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: typer<0.17.0,>=0.12.5 in /usr/local/lib/python3.12/dist-packages (from docling) (0.16.1)
# Collecting python-docx<2.0.0,>=1.1.2 (from docling)
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting python-pptx<2.0.0,>=1.0.2 (from docling)
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.12/dist-packages (from docling) (4.13.5)
# Requirement already satisfied: pandas<3.0.0,>=2.1.4 in /usr/local/lib/python3.12/dist-packages (from docling) (2.2.2)
# Collecting marko<3.0.0,>=2.1.2 (from docling)
#   Downloading marko-2.2.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from docling) (3.1.5)
# Requirement already satisfied: lxml<6.0.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from docling) (5.4.0)
# Requirement already satisfied: pluggy<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from docling) (1.6.0)
# Collecting pylatexenc<3.0,>=2.10 (from docling)
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: accelerate<2,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from docling) (1.10.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling) (5.9.5)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate<2,>=1.0.0->docling) (0.6.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->docling) (2.7)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in /usr/local/lib/python3.12/dist-packages (from docling-core<3.0.0,>=2.42.0->docling-core[chunking]<3.0.0,>=2.42.0->docling) (4.25.1)
# Collecting jsonref<2.0.0,>=1.1.0 (from docling-core<3.0.0,>=2.42.0->docling-core[chunking]<3.0.0,>=2.42.0->docling)
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from docling-core<3.0.0,>=2.42.0->docling-core[chunking]<3.0.0,>=2.42.0->docling) (0.9.0)
# Collecting latex2mathml<4.0.0,>=3.77.0 (from docling-core<3.0.0,>=2.42.0->docling-core[chunking]<3.0.0,>=2.42.0->docling)
#   Downloading latex2mathml-3.78.0-py3-none-any.whl.metadata (14 kB)
# Collecting semchunk<3.0.0,>=2.2.0 (from docling-core[chunking]<3.0.0,>=2.42.0->docling)
#   Downloading semchunk-2.2.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torchvision<1,>=0 in /usr/local/lib/python3.12/dist-packages (from docling-ibm-models<4,>=3.9.0->docling) (0.23.0+cu126)
# Collecting jsonlines<4.0.0,>=3.1.0 (from docling-ibm-models<4,>=3.9.0->docling)
#   Downloading jsonlines-3.1.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: opencv-python-headless<5.0.0.0,>=4.6.0.66 in /usr/local/lib/python3.12/dist-packages (from docling-ibm-models<4,>=3.9.0->docling) (4.12.0.88)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from easyocr<2.0,>=1.7->docling) (0.25.2)
# Collecting python-bidi (from easyocr<2.0,>=1.7->docling)
#   Downloading python_bidi-0.6.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.12/dist-packages (from easyocr<2.0,>=1.7->docling) (2.1.1)
# Collecting pyclipper (from easyocr<2.0,>=1.7->docling)
#   Downloading pyclipper-1.3.0.post6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Collecting ninja (from easyocr<2.0,>=1.7->docling)
#   Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain-groq) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq<1,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.8)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (3.11.2)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (0.24.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl<4.0.0,>=3.1.5->docling) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.1.4->docling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.1.4->docling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.1.4->docling) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.1)
# Collecting XlsxWriter>=0.5.7 (from python-pptx<2.0.0,>=1.0.2->docling)
#   Downloading xlsxwriter-3.2.5-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.4)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.17.0,>=0.12.5->docling) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.17.0,>=0.12.5->docling) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.17.0,>=0.12.5->docling) (13.9.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.42.0->docling-core[chunking]<3.0.0,>=2.42.0->docling) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.42.0->docling-core[chunking]<3.0.0,>=2.42.0->docling) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core<3.0.0,>=2.42.0->docling-core[chunking]<3.0.0,>=2.42.0->docling) (0.27.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.1.4->docling) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<0.17.0,>=0.12.5->docling) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<0.17.0,>=0.12.5->docling) (2.19.2)
# Collecting mpire[dill] (from semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.42.0->docling)
#   Downloading mpire-2.10.2-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.6.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (2025.6.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr<2.0,>=1.7->docling) (0.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.17.0,>=0.12.5->docling) (0.1.2)
# Requirement already satisfied: multiprocess>=0.70.15 in /usr/local/lib/python3.12/dist-packages (from mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.42.0->docling) (0.70.16)
# Requirement already satisfied: dill>=0.3.8 in /usr/local/lib/python3.12/dist-packages (from multiprocess>=0.70.15->mpire[dill]->semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.42.0->docling) (0.3.8)
# Downloading langchain_community-0.3.29-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 69.3 MB/s eta 0:00:00
# Downloading langchain_core-0.3.75-py3-none-any.whl (443 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.0/444.0 kB 30.6 MB/s eta 0:00:00
# Downloading langchain_groq-0.3.7-py3-none-any.whl (16 kB)
# Downloading faiss_cpu-1.12.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 50.4 MB/s eta 0:00:00
# Downloading docling-2.48.0-py3-none-any.whl (212 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.3/212.3 kB 18.0 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading docling_core-2.45.0-py3-none-any.whl (163 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 17.3 MB/s eta 0:00:00
# Downloading docling_ibm_models-3.9.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.6/86.6 kB 6.6 MB/s eta 0:00:00
# Downloading docling_parse-4.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 73.4 MB/s eta 0:00:00
# Downloading easyocr-1.7.2-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 58.5 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading groq-0.31.0-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.4/131.4 kB 14.6 MB/s eta 0:00:00
# Downloading marko-2.2.0-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 4.0 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 57.0 MB/s eta 0:00:00
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 21.4 MB/s eta 0:00:00
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 25.8 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 6.6 MB/s eta 0:00:00
# Downloading rtree-1.4.1-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (507 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.6/507.6 kB 37.3 MB/s eta 0:00:00
# Downloading jsonlines-3.1.0-py3-none-any.whl (8.6 kB)
# Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Downloading latex2mathml-3.78.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 7.0 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.7 MB/s eta 0:00:00
# Downloading semchunk-2.2.2-py3-none-any.whl (10 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading xlsxwriter-3.2.5-py3-none-any.whl (172 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.3/172.3 kB 16.7 MB/s eta 0:00:00
# Downloading ninja-1.13.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (180 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 19.3 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (963 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.8/963.8 kB 58.7 MB/s eta 0:00:00
# Downloading python_bidi-0.6.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (292 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.1/292.1 kB 25.2 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading mpire-2.10.2-py3-none-any.whl (272 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.8/272.8 kB 20.3 MB/s eta 0:00:00
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=063660ac37c2f4feb28391eeee8282a31c5ed7127113a2eb9d9f95878eab066c
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: python-bidi, pylatexenc, pyclipper, filetype, XlsxWriter, rtree, requests, python-docx, pypdfium2, ninja, mypy-extensions, mpire, marshmallow, marko, latex2mathml, jsonref, jsonlines, faiss-cpu, typing-inspect, python-pptx, semchunk, groq, dataclasses-json, langchain-core, docling-core, langchain-groq, easyocr, docling-parse, docling-ibm-models, docling, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.74
#     Uninstalling langchain-core-0.3.74:
#       Successfully uninstalled langchain-core-0.3.74
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# Successfully installed XlsxWriter-3.2.5 dataclasses-json-0.6.7 docling-2.48.0 docling-core-2.45.0 docling-ibm-models-3.9.0 docling-parse-4.2.3 easyocr-1.7.2 faiss-cpu-1.12.0 filetype-1.2.0 groq-0.31.0 jsonlines-3.1.0 jsonref-1.1.0 langchain-community-0.3.29 langchain-core-0.3.75 langchain-groq-0.3.7 latex2mathml-3.78.0 marko-2.2.0 marshmallow-3.26.1 mpire-2.10.2 mypy-extensions-1.1.0 ninja-1.13.0 pyclipper-1.3.0.post6 pylatexenc-2.10 pypdfium2-4.30.0 python-bidi-0.6.6 python-docx-1.2.0 python-pptx-1.0.2 requests-2.32.5 rtree-1.4.1 semchunk-2.2.2 typing-inspect-0.9.0

# %%
import os
import warnings
from docling.document_converter import DocumentConverter
from pathlib import Path
from langchain_text_splitters import MarkdownHeaderTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
import faiss
from langchain_community.vectorstores import FAISS
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain import hub
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq

# %%
# Document conversion
def load_and_convert_document(file_path):
    converter = DocumentConverter()
    result = converter.convert(file_path)
    return result.document.export_to_markdown()

source = "/content/amazon-10-q-q3-2024.pdf"
markdown_content = load_and_convert_document(source)
# Out:
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
# Splitting markdown content into chunks
def get_markdown_splits(markdown_content):
    headers_to_split_on = [("#", "Header 1"), ("##", "Header 2"), ("###", "Header 3")]
    markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on, strip_headers=False)
    return markdown_splitter.split_text(markdown_content)
chunks = get_markdown_splits(markdown_content)

# %%
# Embedding and vector store setup
def setup_vector_store(chunks):
    embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
    single_vector = embeddings.embed_query("this is some text data")
    index = faiss.IndexFlatL2(len(single_vector))
    vector_store = FAISS(
        embedding_function=embeddings,
        index=index,
        docstore=InMemoryDocstore(),
        index_to_docstore_id={}
    )
    vector_store.add_documents(documents=chunks)
    return vector_store

vector_store = setup_vector_store(chunks)

# Setup retriever
retriever = vector_store.as_retriever(search_type="mmr", search_kwargs={'k': 3})
# Out:
# /tmp/ipython-input-2914140663.py:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# %%
# Formatting documents for RAG
def format_docs(docs):
    return "\n\n".join([doc.page_content for doc in docs])

# %%
# Setting up the RAG chain
def create_rag_chain(retriever):
    prompt = """
        You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question.
        If you don't know the answer, just say that you don't know.
        Answer in bullet points. Make sure your answer is relevant to the question and it is answered from the context only.
        Question: {question}
        Context: {context}
        Answer:
    """
    model = ChatGroq(model_name="llama3-8b-8192", api_key = "")  # ✅ Choose a Groq-supported model
    prompt_template = ChatPromptTemplate.from_template(prompt)
    return (
        {"context": retriever | format_docs, "question": RunnablePassthrough()}
        | prompt_template
        | model
        | StrOutputParser()
    )

# %%
# Create RAG chain
rag_chain = create_rag_chain(retriever)

questions = [
    "What was Amazon’s total revenue in Q3 2024?",
    "How does the revenue in Q3 2024 compare to Q3 2023?",
    "What was the net income for Q3 2024, and how does it compare year over year?",
    "What were the earnings per share (basic and diluted) in Q3 2024?",
    "How much did Amazon earn from product vs. service sales?",
    "What were the main operating expense categories and their values in Q3 2024?",
    "What was Amazon’s operating income in Q3 2024?",
    ]


for question in questions:
      print(f"Question: {question}")
      for chunk in rag_chain.stream(question):
          print(chunk, end="", flush=True)
      print("\n" + "-" * 50 + "\n")
# Out:
# Question: What was Amazon’s total revenue in Q3 2024?
# Here are the relevant answers in bullet points:
#
# * Amazon's total revenue in Q3 2024 is not specified in the provided context.
# * The context only mentions unearned revenue and performance obligations, which are not the same as total revenue.
# * The total unearned revenue as of September 30, 2024 is mentioned, but it is not the same as total revenue.
# * The context does not provide the information needed to answer the question about Amazon's total revenue in Q3 2024.
# --------------------------------------------------
#
# Question: How does the revenue in Q3 2024 compare to Q3 2023?
# Here is the answer to the question:
#
# • The context does not provide information on revenue in Q3 2023, only guidance for Q4 2024. Therefore, it is not possible to compare revenue in Q3 2024 to Q3 2023.
# • The context only provides guidance for Q4 2024, not Q3 2024.
# --------------------------------------------------
#
# Question: What was the net income for Q3 2024, and how does it compare year over year?
# Here is the answer to the question in bullet points:
#
# • The net income for Q3 2024 was $15,328 million.
# • Compared to Q3 2023, the net income for Q3 2024 increased by $5,449 million ($15,328 million - $9,879 million).
# --------------------------------------------------
#
# Question: What were the earnings per share (basic and diluted) in Q3 2024?
# Here is the answer to the question:
#
# * I don't know the answer to the question "What were the earnings per share (basic and diluted) in Q3 2024?" because the context does not provide the earnings per share (basic and diluted) for Q3 2024. The context only provides information on the calculation of earnings per share and the diluted shares for Q3 2023 and Q3 2024, but not the actual earnings per share for Q3 2024.
# --------------------------------------------------
#
# Question: How much did Amazon earn from product vs. service sales?
# Based on the provided context, here are the answers to your question:
#
# • The context does not provide a direct breakdown of Amazon's earnings from product vs. service sales. However, it does provide information on net sales, which includes both product and service sales.
# • Net sales include product sales (represented by revenue from the sale of products and related shipping fees and digital media content) and service sales (primarily represented by third-party seller fees, AWS sales, advertising services, Amazon Prime membership fees, and certain digital media content subscriptions).
#
# Since the exact breakdown of earnings from product vs. service sales is not provided, I cannot provide a specific answer to this question.
# --------------------------------------------------
#
# Question: What were the main operating expense categories and their values in Q3 2024?
# Here are the main operating expense categories and their values in Q3 2024:
#
# • Other operating expense (income), net: $244 million
# --------------------------------------------------
#
# Question: What was Amazon’s operating income in Q3 2024?
# Here are the answers to the question "What was Amazon’s operating income in Q3 2024?" in bullet points:
#
# • Amazon's operating income in Q3 2024 was $5,663 million.
# • This information can be found in the "Operating income" column under the "AWS" segment in the table titled "Information on reportable segments and reconciliation to consolidated net income is as follows (in millions)".
# --------------------------------------------------

# %%
# Main execution logic
if __name__ == "__main__":
    # Load document
    source = "/content/amazon-10-q-q3-2024.pdf"
    markdown_content = load_and_convert_document(source)
    chunks = get_markdown_splits(markdown_content)

    # Create vector store
    vector_store = setup_vector_store(chunks)

    # Setup retriever
    retriever = vector_store.as_retriever(search_type="mmr", search_kwargs={'k': 3})

    # Create RAG chain
    rag_chain = create_rag_chain(retriever)

    # Questions for retrieval
    # Questions for retrieval (Amazon-specific)
    questions = [
    # Financial Performance
    "What was Amazon’s total revenue in Q3 2024?",
    "How does the revenue in Q3 2024 compare to Q3 2023?",
    "What was the net income for Q3 2024, and how does it compare year over year?",
    "What were the earnings per share (basic and diluted) in Q3 2024?",
    "How much did Amazon earn from product vs. service sales?",
    "What were the main operating expense categories and their values in Q3 2024?",
    "What was Amazon’s operating income in Q3 2024?",
    ]



    # Answer questions
    for question in questions:
        print(f"Question: {question}")
        for chunk in rag_chain.stream(question):
            print(chunk, end="", flush=True)
        print("\n" + "-" * 50 + "\n")
# Out:
# Question: What was Amazon’s total revenue in Q3 2024?
# Here are the answers to the question in bullet points:
#
# • The context does not mention Amazon's total revenue in Q3 2024. The closest information is about unearned revenue, which was $12.5 billion recognized as revenue during the nine months ended September 30, 2024. However, this is not the total revenue for Q3 2024.
# • The context does not provide information about Amazon's total revenue in Q3 2024. Therefore, the answer is "I don't know".
# --------------------------------------------------
#
# Question: How does the revenue in Q3 2024 compare to Q3 2023?
# Here is the answer to the question in bullet points, based on the retrieved context:
#
# • The context does not provide specific revenue figures for Q3 2024 and Q3 2023. However, it provides guidance for Q4 2024, which is the quarter that includes Q3 2024.
# • The guidance for Q4 2024 indicates that net sales are expected to be between $181.5 billion and $188.5 billion, which represents a growth between 7% and 11% compared to Q4 2023.
# • The guidance does not provide specific revenue figures for Q3 2023, so it is not possible to determine how Q3 2024 revenue compares to Q3 2023 revenue.
# • However, the guidance does provide information on Q4 2023 revenue, which may be used to estimate Q3 2023 revenue.
# --------------------------------------------------
#
# Question: What was the net income for Q3 2024, and how does it compare year over year?
# Here are the answers to the question in bullet points:
#
# • The net income for Q3 2024 was $15,328 million.
# • Compared year over year, the net income for Q3 2024 is higher than the net income for Q3 2023, which was $9,879 million.
# --------------------------------------------------
#
# Question: What were the earnings per share (basic and diluted) in Q3 2024?
# Here is the answer to the question in bullet points:
#
# • There is no information about the earnings per share (basic and diluted) in Q3 2024 in the provided context.
#
# • The provided context only includes information about the calculation of diluted earnings per share, but it does not provide the actual earnings per share amounts for Q3 2024.
#
# • The context also includes guidance for the fourth quarter of 2024, but it does not include the earnings per share information for that quarter.
#
# • Therefore, I do not have the answer to this question based on the provided context.
# --------------------------------------------------
#
# Question: How much did Amazon earn from product vs. service sales?
# Here are the answers to your question in bullet points, based on the provided context:
#
# • The context does not provide a direct answer to the question of how much Amazon earned from product vs. service sales. However, it does provide information on the composition of net sales, which includes both product and service sales.
# • The table provided in the context shows the net sales by category, including North America, International, AWS, and Consolidated. It also shows the percentage growth of each category.
# • The context states that product sales represent revenue from the sale of products and related shipping fees and digital media content where we record revenue gross. This implies that product sales include revenue from the sale of physical products, as well as digital media content and shipping fees.
# • Service sales, on the other hand, primarily represent third-party seller fees, which includes commissions and any related fulfillment and shipping fees, AWS sales, advertising services, Amazon Prime membership fees, and certain digital media content subscriptions. This implies that service sales include revenue from services such as AWS, advertising, and Prime membership, as well as fees from third-party sellers.
# • Unfortunately, the context does not provide a breakdown of net sales by product and service sales, so it is not possible to determine the exact amount earned from each category.
# --------------------------------------------------
#
# Question: What were the main operating expense categories and their values in Q3 2024?
# Here is the answer to the question in bullet points, based on the provided context:
#
# • The main operating expense categories mentioned in the context are not explicitly listed, but they are referred to as:
# 	+ variations in merchandise and vendor returns
# 	+ investment in technology and infrastructure, fulfillment, and other expense categories
# 	+ availability of and increases in the prices of transportation, resources, commodities, and technology infrastructure products
# 	+ constrained labor markets
# 	+ other expense categories (e.g. asset impairments and amortization of intangible assets)
#
# • The values for these categories are not provided in the given context.
# --------------------------------------------------
#
# Question: What was Amazon’s operating income in Q3 2024?
# Here is the answer to the question in bullet points:
#
# • The context provided does not mention Amazon's operating income in Q3 2024. However, it does provide information on Amazon's operating income for Q3 2023 and Q3 2024 in the "Consolidated" section:
# • For Q3 2023, Amazon's operating income was $11,188 million.
# • For Q3 2024, Amazon's operating income was $17,411 million.
#
# Note that the context does not provide the exact operating income for Q3 2024, but it does provide the operating income for the nine months ended September 30, 2024, which is $47,390 million.
# --------------------------------------------------

# %%
# Interface

# %%
import gradio as gr

# Global variable to store vector store and RAG chain after file upload
vector_store = None
rag_chain = None

def upload_and_process(file):
    global vector_store, rag_chain
    file_path = file.name
    markdown_content = load_and_convert_document(file_path)
    chunks = get_markdown_splits(markdown_content)
    vector_store = setup_vector_store(chunks)
    retriever = vector_store.as_retriever(search_type="mmr", search_kwargs={'k': 3})
    rag_chain = create_rag_chain(retriever)
    return "✅ Document processed and RAG chain created. You can now ask questions."

def ask_question(question):
    if rag_chain is None:
        return "❌ Please upload and process a document first."
    response = ""
    for chunk in rag_chain.stream(question):
        response += chunk
    return response

# Launch Gradio interface
with gr.Blocks() as demo:
    gr.Markdown("## 📊 Amazon 10-Q RAG-Based QA System using Groq + FAISS")

    with gr.Row():
        with gr.Column():
            file_input = gr.File(label="📁 Upload Amazon 10-Q PDF", file_types=[".pdf"])
            upload_btn = gr.Button("🔄 Upload & Process")
            upload_output = gr.Textbox(label="Processing Status", lines=2)

        with gr.Column():
            question_input = gr.Textbox(label="❓ Ask a Question", placeholder="e.g. What was Amazon’s total revenue in Q3 2024?")
            ask_btn = gr.Button("🔍 Get Answer")
            answer_output = gr.Textbox(label="📢 Answer", lines=10)

    upload_btn.click(fn=upload_and_process, inputs=[file_input], outputs=[upload_output])
    ask_btn.click(fn=ask_question, inputs=[question_input], outputs=[answer_output])

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://4879b5745164bd2810.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4879b5745164bd2810.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Main execution logic
if __name__ == "__main__":
    # Load document
    source = "/content/amazon-10-q-q3-2024.pdf"
    markdown_content = load_and_convert_document(source)
    chunks = get_markdown_splits(markdown_content)

    # Create vector store
    vector_store = setup_vector_store(chunks)

    # Setup retriever
    retriever = vector_store.as_retriever(search_type="mmr", search_kwargs={'k': 3})

    # Create RAG chain
    rag_chain = create_rag_chain(retriever)

    # Questions for retrieval
    # Questions for retrieval (Amazon-specific)
    questions = [
    # Financial Performance
    "What was Amazon’s total revenue in Q3 2024?",
    "How does the revenue in Q3 2024 compare to Q3 2023?",
    "What was the net income for Q3 2024, and how does it compare year over year?",
    "What were the earnings per share (basic and diluted) in Q3 2024?",
    "How much did Amazon earn from product vs. service sales?",
    "What were the main operating expense categories and their values in Q3 2024?",
    "What was Amazon’s operating income in Q3 2024?",

    # Segment Analysis
    "What was the revenue and operating income for Amazon Web Services (AWS) in Q3 2024?",
    "How did the North America and International segments perform in terms of revenue and profit?",
    "Which segment contributed the most to Amazon’s operating income?",

    # Cash Flow & Capital Expenditures
    "How much cash did Amazon generate from operating activities?",
    "What were the major uses of cash in investing and financing activities?",
    "What were Amazon’s capital expenditures in Q3 2024?",

    # Debt and Liabilities
    "What is Amazon’s total long-term debt as of September 30, 2024?",
    "What are the upcoming debt maturities and interest rates for Amazon's outstanding bonds?",

    # Stock & Shareholder Equity
    "What were the changes in stockholders’ equity this quarter?",
    "Did Amazon repurchase any stock in Q3 2024?",

    # Other Financial Indicators
    "What are the values of accounts receivable, inventories, and marketable securities as of September 30, 2024?",
    "What were Amazon’s total assets and liabilities?",

    # Legal and Regulatory
    "What major legal proceedings or lawsuits was Amazon involved in during Q3 2024?",
    "What was the outcome of the Kove IO patent case?",
    "Are there any significant antitrust or consumer protection investigations ongoing?",

    # Taxation and Accounting
    "What is Amazon’s effective tax rate for Q3 2024?",
    "What discrete tax items impacted Amazon’s tax expense?",
    "Are there any significant tax disputes or contingencies noted?",

    # Revenue Breakdown
    "What was the revenue breakdown by business line (Online stores, AWS, advertising, etc.)?",
    "How did subscription services and advertising revenue perform compared to last year?"
]



    # Answer questions
    for question in questions:
        print(f"Question: {question}")
        for chunk in rag_chain.stream(question):
            print(chunk, end="", flush=True)
        print("\n" + "-" * 50 + "\n")
# Out:
# Question: What was Amazon’s total revenue in Q3 2024?
# Here is the answer to the question:
#
# * The context provided does not mention Amazon's total revenue in Q3 2024. The closest information provided is about unearned revenue and performance obligations, but it does not provide information about total revenue.
# * Therefore, the answer is: I don't know.
# --------------------------------------------------
#
# Question: How does the revenue in Q3 2024 compare to Q3 2023?
# Here is the answer in bullet points:
#
# • The context does not provide direct information on the revenue in Q3 2024 compared to Q3 2023. However, it provides guidance for the fourth quarter of 2024, which expects net sales to grow between 7% and 11% compared to fourth quarter 2023.
# • The guidance for Q4 2024 is not specific to Q3 2024, as it provides a range for the entire quarter, not just Q3.
# • Therefore, the answer to the question is that there is no information provided in the context to compare the revenue in Q3 2024 to Q3 2023.
# --------------------------------------------------
#
# Question: What was the net income for Q3 2024, and how does it compare year over year?
# Here is the answer to the question:
#
# * The net income for Q3 2024 was $15,328 million.
# * Compared year-over-year, the net income for Q3 2024 increased by $5,449 million from Q3 2023, which was $9,879 million.
# --------------------------------------------------
#
# Question: What were the earnings per share (basic and diluted) in Q3 2024?
# Here is the answer to the question:
#
# * I don't know the earnings per share (basic and diluted) in Q3 2024 because the provided context does not include the earnings per share information for the third quarter of 2024. The context only includes information for 2023 and 2024's fourth quarter guidance, as well as the consolidated balance sheets for December 31, 2023, and September 30, 2024.
# --------------------------------------------------
#
# Question: How much did Amazon earn from product vs. service sales?
# Here are the answers to your question based on the provided context:
#
# • The context provides information on net sales, which includes both product and service sales. However, it does not provide a breakdown of the specific amounts earned from product vs. service sales.
# • The context does provide information on the composition of net sales, including product sales and service sales, but it does not provide a separate breakdown of the revenue generated from each.
# • Therefore, I do not have the information to answer the question of how much Amazon earned from product vs. service sales.
#
# I hope this helps!
# --------------------------------------------------
#
# Question: What were the main operating expense categories and their values in Q3 2024?
# Unfortunately, the provided context does not mention the main operating expense categories and their values in Q3 2024. The text only mentions the value of Other operating expense (income), net for Q3 2023 and Q3 2024, which is $244 million and $262 million, respectively.
#
# However, the context does not provide information on the breakdown of operating expenses into specific categories, such as labor, transportation, or technology expenses. Therefore, I don't have the answer to the question.
# --------------------------------------------------
#
# Question: What was Amazon’s operating income in Q3 2024?
# Based on the provided context, I found the following information related to Amazon's operating income:
#
# * For Q3 2023, Amazon's operating income was $4,307 million.
# * For Q3 2024, Amazon's operating income was $5,663 million.
# * For the nine months ended September 30, 2023, Amazon's operating income was $8,416 million.
# * For the nine months ended September 30, 2024, Amazon's operating income was $15,711 million.
#
# Please note that the provided context only contains data up to Q3 2024, so it does not include information about Q3 2025 or later.
# --------------------------------------------------
#
# Question: What was the revenue and operating income for Amazon Web Services (AWS) in Q3 2024?
# Here is the answer to your question:
#
# • Revenue: Not mentioned in the provided context.
# • Operating Income: Not mentioned in the provided context.
#
# Note: The context provides information about unearned revenue, performance obligations, and other operating expenses, but it does not mention the specific revenue and operating income figures for Amazon Web Services (AWS) in Q3 2024.
# --------------------------------------------------
#
# Question: How did the North America and International segments perform in terms of revenue and profit?
# Here are the answers to the question in bullet points:
#
# • The North America segment performed well in terms of revenue and profit, with operating income increasing from $4,307 million in Q3 2023 to $5,663 million in Q3 2024, and from $8,416 million for the nine months ended September 30, 2023 to $15,711 million for the nine months ended September 30, 2024.
#
# • The International segment also performed well, turning an operating loss of $95 million in Q3 2023 into an operating income of $1,301 million in Q3 2024, and an operating loss of $2,237 million for the nine months ended September 30, 2023 into an operating income of $2,477 million for the nine months ended September 30, 2024.
# --------------------------------------------------
#
# Question: Which segment contributed the most to Amazon’s operating income?
# Here is the answer to the question:
#
# * According to the provided context, there is no direct information that specifies which segment contributed the most to Amazon's operating income. The context only provides information about the segments (North America, International, and AWS) and how they are organized, but it does not provide specific financial data to answer this question.
# --------------------------------------------------
#
# Question: How much cash did Amazon generate from operating activities?
# Here are the answers to your question in bullet points:
#
# • According to the context, Amazon generated:
# 	+ $71,654 in net cash provided by operating activities for the twelve months ended September 30, 2023.
# 	+ $112,706 in net cash provided by operating activities for the twelve months ended September 30, 2024.
# --------------------------------------------------
#
# Question: What were the major uses of cash in investing and financing activities?
# Here are the major uses of cash in investing and financing activities based on the provided context:
#
# * Investing activities:
# 	+ Acquisitions: acquisition of 1Life Healthcare, Inc. (One Medical) in 2023 with cash on hand
# 	+ Investments: invested $1.25 billion in a convertible note from Anthropic in Q3 2023 and $2.75 billion in a second convertible note in Q1 2024
# 	+ Property and equipment acquired under finance leases: $183 million and $186 million during Q3 2023 and Q3 2024, and $431 million and $409 million for the nine months ended September 30, 2023 and 2024
# * Financing activities:
# 	+ Cash flows from financing activities: proceeds from short-term debt, and other and long-term debt of $216 million and $1.7 billion for Q3 2023 and Q3 2024, and $17.4 billion and $2.6 billion for the nine months ended September 30, 2023 and 2024
# 	+ Cash outflows from financing activities: payments of short-term debt, and other, long-term debt, finance leases, and financing obligations of $9.2 billion and $4.5 billion in Q3 2023 and Q3 2024, and $26.5 billion and $11.1 billion for the nine months ended September 30, 2023 and 2024
# --------------------------------------------------
#
# Question: What were Amazon’s capital expenditures in Q3 2024?
# Here is the answer to the question in bullet points:
#
# • Amazon's capital expenditures are mentioned in the context, but the specific amount for Q3 2024 is not provided.
# • The text only discusses the increase in technology and infrastructure costs in Q3 2024 compared to the prior year period, but does not provide a specific dollar amount for capital expenditures.
# • The context does not provide the answer to the question.
# --------------------------------------------------
#
# Question: What is Amazon’s total long-term debt as of September 30, 2024?
# • I don't know the total long-term debt of Amazon as of September 30, 2024, as the provided context does not mention the specific amount of long-term debt.
# --------------------------------------------------
#
# Question: What are the upcoming debt maturities and interest rates for Amazon's outstanding bonds?
# Unfortunately, I don't have any information regarding upcoming debt maturities and interest rates for Amazon's outstanding bonds in the provided context. The context only mentions a 364-Day Revolving Credit Agreement and some general information about market risk for changes in interest rates, but it does not provide specific details about Amazon's outstanding bonds.
# --------------------------------------------------
#
# Question: What were the changes in stockholders’ equity this quarter?
# Here are the changes in stockholders' equity for the quarter:
#
# * Beginning total stockholders' equity: $236,447
# * Ending total stockholders' equity: $259,151
# * Change: $22,704 ($259,151 - $236,447)
#
# Note: The context does not provide a specific breakdown of the changes in each component of stockholders' equity, only the total change.
# --------------------------------------------------
#
# Question: Did Amazon repurchase any stock in Q3 2024?
# Here is the answer to the question:
#
# * According to the context, there were no repurchases of Amazon's common stock during the nine months ended September 30, 2024.
# * Therefore, the answer to the question "Did Amazon repurchase any stock in Q3 2024?" is:
# 	+ No
# --------------------------------------------------
#
# Question: What are the values of accounts receivable, inventories, and marketable securities as of September 30, 2024?
# Here are the values of accounts receivable, inventories, and marketable securities as of September 30, 2024:
#
# * Accounts receivable, net and other: $34.6 billion (customer receivables, net), $8.3 billion (vendor receivables, net), $60 million (seller receivables, net), and $3.0 billion (other receivables, net), for a total of $46.9 billion.
# * Inventories: Not mentioned in the provided context.
# * Marketable securities: $88,051 million (total cash, cash equivalents, and marketable securities) - $3,586 million (restricted cash, cash equivalents, and marketable securities) = $84,465 million.
# --------------------------------------------------
#
# Question: What were Amazon’s total assets and liabilities?
# Here is the answer to the question:
#
# * The context does not mention Amazon's total assets. Therefore, the answer is unknown.
# * As for liabilities, the context mentions:
# 	+ $5.7 billion of unearned revenue as of December 31, 2023 (included in 'Other long-term liabilities' on the consolidated balance sheet)
# 	+ $7.0 billion of unearned revenue as of September 30, 2024 (included in 'Other long-term liabilities' on the consolidated balance sheet)
# 	+ $164 billion of commitments not yet recognized as of September 30, 2024 (primarily related to AWS)
# --------------------------------------------------
#
# Question: What major legal proceedings or lawsuits was Amazon involved in during Q3 2024?
# Here are the major legal proceedings or lawsuits that Amazon was involved in during Q3 2024, based on the provided context:
#
# • Kove IO, Inc. v. Amazon Web Services, Inc. - In April 2024, a jury found that Amazon infringed the asserted patents and awarded Kove $525 million in damages. In August 2024, the court awarded Kove $148 million in pre-judgment interest. Amazon filed a notice of appeal in September 2024.
#
# • Frame-Wilson v. Amazon.com, Inc. - Private litigants have filed a number of cases in the U.S. and Canada alleging price fixing arrangements between Amazon.com, Inc. and vendors and third-party sellers in Amazon's stores, monopolization and attempted monopolization, and consumer protection and unjust enrichment claims. The Federal Trade Commission and a number of state Attorneys General filed a similar lawsuit in September 2023.
#
# • De Coster v. Amazon.com, Inc. - Amazon's motions to dismiss were granted in part and denied in part in March 2022 and March 2023.
#
# • Broadband iTV, Inc. v. Amazon.com, Inc., Amazon.com Services LLC, and Amazon Web Services, Inc. - The complaint alleges that certain Amazon Prime Video features and services infringe U.S. Patent Nos. 9,648,388, 10,546,750, and 10,536,751, each entitled 'Video-On-Demand Content Delivery System for Providing Video-On-Demand Services to TV Services Subscribers'.
#
# • May 2024 lawsuit by the Attorney General of Arizona - The complaint alleges that Amazon's practices related to pricing and the Featured Offers in its stores violate state antitrust and consumer protection laws.
#
# • August 2024 decision by the DC Court of Appeals - The court overturned a prior decision by the DC Superior Court dismissing the DC Attorney General's lawsuit.
#
# • September 2024 decision by the United States District Court for the W.D. Wash. - The court granted in part Amazon's motion to dismiss the suit brought by the FTC and certain state Attorneys General with respect to five state law claims and denied the motion with respect to the remaining claims.
# --------------------------------------------------
#
# Question: What was the outcome of the Kove IO patent case?
# Here is the answer to the question "What was the outcome of the Kove IO patent case?" based on the provided context:
#
# • In December 2018, Kove IO, Inc. filed a complaint against Amazon Web Services, Inc. in the United States District Court for the Northern District of Illinois.
# • In April 2024, a jury found that Amazon infringed the asserted patents and awarded Kove $525 million in damages.
# • In August 2024, the court awarded Kove $148 million in pre-judgment interest.
# • In September 2024, we filed a notice of appeal.
# --------------------------------------------------
#
# Question: Are there any significant antitrust or consumer protection investigations ongoing?
# Here are the relevant points from the context that answer the question:
#
# * There are claims, litigation, reviews, investigations, and other proceedings involving a wide range of issues, including competition and antitrust.
# * The company is litigating matters alleging price fixing, monopolization, and consumer protection claims, including those brought by state attorneys general and the Federal Trade Commission.
# * The outcomes of these matters are inherently unpredictable and subject to significant uncertainties.
# * The company may be exposed to losses in excess of the amount recorded until the final resolution of such matters.
#
# Therefore, to answer the question: Yes, there are significant antitrust and consumer protection investigations ongoing, as evidenced by the company's litigation of matters alleging price fixing, monopolization, and consumer protection claims.
# --------------------------------------------------
#
# Question: What is Amazon’s effective tax rate for Q3 2024?
# Here are the answers to the question:
#
# • The context does not provide Amazon's effective tax rate for Q3 2024.
# • The context only provides guidance on forward-looking statements and discusses various factors that could affect Amazon's effective tax rate, but does not provide the actual effective tax rate for Q3 2024.
# --------------------------------------------------
#
# Question: What discrete tax items impacted Amazon’s tax expense?
# Here are the discrete tax items that impacted Amazon's tax expense, as mentioned in the provided context:
#
# • Net discrete tax expense of $175 million for the nine months ended September 30, 2023
# • Net discrete tax benefits of $2.4 billion primarily attributable to excess tax benefits from stock-based compensation for the nine months ended September 30, 2024
# --------------------------------------------------
#
# Question: Are there any significant tax disputes or contingencies noted?
# Here is the answer to the question:
#
# * Yes, there are significant tax disputes or contingencies noted.
# * The company is disputing claims and denials of refunds or credits related to non-income taxes, including sales, value added, consumption, service, and similar taxes.
# * The company is also currently subject to tax controversies in various jurisdictions, and these jurisdictions may assess additional income tax liabilities against the company.
# * The company regularly assesses the likelihood of an adverse outcome resulting from these proceedings to determine the adequacy of its tax accruals.
# * The final outcome of audits, investigations, and any other tax controversies could be materially different from the company's historical income tax provisions and accruals.
# --------------------------------------------------
#
# Question: What was the revenue breakdown by business line (Online stores, AWS, advertising, etc.)?
# Here is the answer to the question in bullet points:
#
# • The revenue breakdown by business line is not explicitly provided in the given context, but the following figures are available:
# 	+ North America: $87,887 million (Q3 2023), $95,537 million (Q3 2024), $247,314 million (9M 2023), and $271,911 million (9M 2024)
# 	+ International: $32,137 million (Q3 2023), $35,888 million (Q3 2024), $90,957 million (9M 2023), and $99,486 million (9M 2024)
# 	+ AWS: $23,059 million (Q3 2023), $27,452 million (Q3 2024), $66,553 million (9M 2023), and $78,770 million (9M 2024)
# • However, the total consolidated revenue is provided: $143,083 million (Q3 2023), $158,877 million (Q3 2024), $404,824 million (9M 2023), and $450,167 million (9M 2024)
# --------------------------------------------------
#
# Question: How did subscription services and advertising revenue perform compared to last year?
# Here are the answers to your question in bullet points:
#
# • Subscription services: The subscription services revenue for Q3 2024 was $11,278 million, which is an increase of $1,108 million compared to the same period last year. For the nine months ended September 30, 2024, subscription services revenue was $32,866 million, an increase of $3,145 million compared to the same period last year.
#
# • Advertising revenue: The advertising services revenue for Q3 2024 was $14,331 million, which is an increase of $2,271 million compared to the same period last year. For the nine months ended September 30, 2024, advertising services revenue was $38,926 million, an increase of $6,674 million compared to the same period last year.
#
# Note that these answers are based only on the provided context and may not reflect the complete financial picture of the company.
# --------------------------------------------------
